# %% [markdown]
# ### Compute the 1-D inverse discrete Fourier Transform.

# %%
import scipy.fft
scipy.fft.ifft([0, 4, 0, 0])
# Out:
# array([ 1.-0.j,  0.+1.j, -1.-0.j,  0.-1.j])

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
rng = np.random.default_rng()
t = np.arange(400)
n = np.zeros((400,), dtype=complex)
n[40:60] = np.exp(1j*rng.uniform(0, 2*np.pi, (20,)))
s = scipy.fft.ifft(n)
plt.plot(t, s.real, 'b-', t, s.imag, 'r--')
# Out:
# [<matplotlib.lines.Line2D at 0x25f6d93c190>,
#  <matplotlib.lines.Line2D at 0x25f6cf5ff70>]

# %%
plt.legend(('real', 'imaginary'))

# %%
plt.show()

# %%
def ifft(X):
    ''' IFFT of 1-d signals
    usage x = ifft(X) 
    unpadding must be done implicitly'''

    x = scipy.fft.fft([x.conjugate() for x in X])
    return [x.conjugate()/len(X) for x in x]

# %%
ifft([0, 4, 0, 0])
# Out:
# [(1+0j), 1j, (-1+0j), -1j]
